# %%
import requests, re
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
url = 'https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page='

# %%
s = requests.Session()
r = s.get(url,timeout=10)
r
# Out:
# <Response [200]>

# %%
c = r.content

# %%
soup = BeautifulSoup(c, 'html.parser')

# %%
soup.title.string
# Out:
# 'Flats for Rent in Lagos | 239,620 Listings | Nigeria Property Centre'

# %%
prop_title = soup.find_all('h3', {'itemprop':'name'})
prop_title[0].get_text()
# Out:
# 'An Exquisite And Luxurious 3 Bedroom Apartment'

# %%
description = soup.find_all('h4', {'class':'content-title'})
description[0].get_text()
# Out:
# '3 bedroom flat / apartment for rent'

# %%
location = soup.find_all('address', {'class':'voffset-bottom-10'})
location[7].get_text().strip().split()[-2]
# Out:
# 'Lekki,'

# %%
price = soup.find_all('span', {'class':'price'})
price[1]
# Out:
# <span class="price" content="15000000.00">15,000,000</span>

# %%
price = soup.find_all('span', {'class':'pull-sm-left'})
price[0].get_text().strip().split('₦')[1].split(' ')[0]
# Out:
# '15,000,000'

# %%
price_period = soup.find_all('span', {'class':'pull-sm-left'})
price_period[0].get_text().strip().split('₦')[1].split(' ' )[1:]
# Out:
# ['per', 'annum']

# %%
features = soup.find_all('ul', {'class':'aux-info'})
features[9].get_text()
# Out:
# '3 Bedrooms3 Bathrooms4 Toilets2 Parking Spaces Save'

# %%
bedroom = re.findall("..Bedroom|..Bedrooms",features[9].get_text().strip())
bedroom
# Out:
# ['3 Bedroom']

# %%
bathroom = re.findall("..Bathrooms|..Bathroom",features[9].get_text().strip())
bathroom
# Out:
# ['3 Bathrooms']

# %%
toilets = re.findall("..Toilets",features[0].get_text().strip())
toilets
# Out:
# ['4 Toilets']

# %%
garage = re.findall("..Parking Spaces",features[0].get_text().strip())
garage
# Out:
# ['3 Parking Spaces']

# %%
soup.find_all('span',{'class':'pagination-results'})[0].get_text().strip().split()[-1].replace(',','')
# Out:
# '9438'

# %%
items = int(soup.find_all('span',{'class':'pagination-results'})[0].get_text().strip().split()[-1].replace(',',''))
listings = 30
page_nr = int(items/listings)
page_nr
# Out:
# 312

# %%
scraped=[]

base_url='https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page='

items = int(soup.find_all('span',{'class':'pagination-results'})[0].get_text().strip().split()[-1].replace(',',''))
listings = 30
page_nr = int(items/listings)

for page in range(1,int(page_nr),1):
    print(base_url+str(page))
    r= requests.get(base_url+str(page))
    c= r.content
    soup= BeautifulSoup(c,"html.parser")
        
    classes = ["itemListElement"]
    for class_ in classes:
        real=soup.find_all("div",{"itemprop":class_})

        for i in list(range(0,len(real))):
            d={}
            d["page" ] = page
            try:
                d["title"]=real[i].find('h3', {'itemprop':'name'}).get_text().strip()
            except (IndexError,TypeError,AttributeError) as e:
                d["title"]= None
            try:
                d["description"]=real[i].find('h4', {'class':'content-title'}).get_text().strip()
            except (IndexError,TypeError,AttributeError) as e:
                d["description"]= None
            try:
                d["bedrooms"]= re.findall("..Bedroom|..Bedrooms",real[i].find('ul', {'class':'aux-info'}).get_text().strip())[0][0]
            except (IndexError,TypeError,AttributeError) as e:
                d["bedrooms"]= None 
            try:
                d["bathrooms"]= re.findall("..Bathroom|..Bathrooms",real[i].find('ul', {'class':'aux-info'}).get_text().strip())[0][0]
            except (IndexError,TypeError,AttributeError) as e:
                d["bathrooms"]= None
            try:
                d["toilets"] = re.findall("..Toilet|..Toilets",real[i].find('ul', {'class':'aux-info'}).get_text().strip())[0][0]
            except (IndexError,TypeError,AttributeError) as e:
                d["toilets"] = None
            try:
                d["garage"] = re.findall("..Parking Space",real[i].find('ul', {'class':'aux-info'}).get_text().strip())[0][0]
            except (IndexError,TypeError,AttributeError) as e:
                d["garage"] = None
            try:
                d["location"] = real[i].find('address', {'class':'voffset-bottom-10'}).get_text().strip()
            except (IndexError,TypeError,AttributeError):
                d["location"] = None
            try:
                d["location_s"] = real[i].find('address', {'class':'voffset-bottom-10'}).get_text().strip().split()[-2]
            except(IndexError,TypeError,AttributeError):
                d['location_s'] = None
            try:
                d["price"]=real[i].find('span', {'class':'pull-sm-left'}).get_text().strip().split('₦')[1].split(' ')[0]
            except (IndexError,TypeError,AttributeError) as e:
                d["price"] = None            
            scraped.append(d)
            #print(l)
# Out:
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=1
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=2
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=3
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=4
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=5
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=6
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=7
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=8
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=9
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=10
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=11
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=12
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=13
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=14
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=15
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=16
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=17
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=18
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=19
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=20
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=21
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=22
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=23
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=24
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=25
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=26
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=27
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=28
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=29
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=30
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=31
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=32
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=33
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=34
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=35
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=36
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=37
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=38
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=39
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=40
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=41
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=42
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=43
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=44
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=45
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=46
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=47
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=48
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=49
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=50
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=51
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=52
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=53
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=54
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=55
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=56
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=57
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=58
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=59
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=60
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=61
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=62
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=63
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=64
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=65
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=66
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=67
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=68
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=69
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=70
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=71
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=72
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=73
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=74
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=75
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=76
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=77
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=78
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=79
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=80
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=81
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=82
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=83
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=84
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=85
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=86
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=87
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=88
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=89
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=90
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=91
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=92
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=93
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=94
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=95
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=96
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=97
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=98
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=99
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=100
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=101
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=102
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=103
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=104
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=105
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=106
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=107
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=108
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=109
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=110
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=111
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=112
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=113
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=114
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=115
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=116
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=117
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=118
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=119
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=120
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=121
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=122
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=123
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=124
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=125
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=126
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=127
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=128
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=129
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=130
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=131
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=132
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=133
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=134
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=135
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=136
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=137
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=138
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=139
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=140
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=141
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=142
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=143
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=144
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=145
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=146
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=147
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=148
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=149
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=150
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=151
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=152
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=153
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=154
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=155
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=156
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=157
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=158
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=159
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=160
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=161
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=162
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=163
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=164
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=165
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=166
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=167
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=168
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=169
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=170
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=171
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=172
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=173
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=174
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=175
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=176
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=177
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=178
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=179
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=180
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=181
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=182
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=183
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=184
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=185
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=186
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=187
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=188
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=189
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=190
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=191
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=192
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=193
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=194
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=195
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=196
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=197
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=198
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=199
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=200
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=201
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=202
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=203
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=204
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=205
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=206
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=207
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=208
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=209
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=210
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=211
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=212
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=213
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=214
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=215
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=216
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=217
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=218
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=219
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=220
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=221
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=222
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=223
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=224
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=225
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=226
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=227
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=228
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=229
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=230
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=231
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=232
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=233
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=234
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=235
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=236
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=237
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=238
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=239
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=240
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=241
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=242
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=243
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=244
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=245
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=246
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=247
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=248
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=249
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=250
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=251
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=252
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=253
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=254
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=255
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=256
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=257
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=258
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=259
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=260
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=261
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=262
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=263
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=264
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=265
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=266
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=267
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=268
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=269
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=270
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=271
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=272
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=273
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=274
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=275
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=276
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=277
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=278
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=279
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=280
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=281
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=282
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=283
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=284
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=285
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=286
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=287
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=288
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=289
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=290
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=291
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=292
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=293
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=294
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=295
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=296
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=297
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=298
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=299
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=300
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=301
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=302
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=303
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=304
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=305
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=306
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=307
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=308
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=309
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=310
# https://nigeriapropertycentre.com/for-rent/flats-apartments/lagos/showtype?page=311

# %%
df = pd.DataFrame(scraped)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f07167541ce8> in <module>
# ----> 1 df = pd.DataFrame(scraped)
#       2 df
#
# NameError: name 'scraped' is not defined

# %%
df[df.duplicated()]
# Out:
#       page                                              title  \
# 1811    87                                     3 Bedroom Flat
# 2539   121     An Exquisite And Luxurious 3 Bedroom Apartment
# 3394   162                                     2 Bedroom Flat
# 3395   162                    Room And Parlour Self Contained
# 3469   166                                 Spacious Mini Flat
# 3472   166                                 Spacious Mini Flat
# 4029   192                                     3 Bedroom Flat
# 4245   203                                     2 Bedroom Flat
# 4300   205  Newly Built Luxury 3 Bedroom Fully Finished An...
# 4336   207                                         2 Bedrooms
# 4338   207                                         3 Bedrooms
#
#                                           description bedrooms bathrooms  \
# 1811              3 bedroom flat / apartment for rent        3         3
# 2539              3 bedroom flat / apartment for rent        3         3
# 3394              2 bedroom flat / apartment for rent        2         2
# 3395  1 bedroom mini flat (room and parlour) for rent        1         1
# 3469  1 bedroom mini flat (room and parlour) for rent        1         1
# 3472  1 bedroom mini flat (room and parlour) for rent        1         1
# 4029              3 bedroom flat / apartment for rent        3         3
# 4245              2 bedroom flat / apartment for rent        2         2
# 4300              3 bedroom flat / apartment for rent        3         4
# 4336              2 bedroom flat / apartment for rent        2         2
# 4338              3 bedroom flat / apartment for rent        3         3
#
#      toilets garage                                      location location_s  \
# 1811       4      2                   Lekki Phase 1, Lekki, Lagos     Lekki,
# 2539       4      3                                  Ikoyi, Lagos     Ikoyi,
# 3394       3      2                          Orchid, Lekki, Lagos     Lekki,
# 3395       2      2                          Orchid, Lekki, Lagos     Lekki,
# 3469       1   None  Off Agungi Ajiran Road, Agungi, Lekki, Lagos     Lekki,
# 3472       1   None  Off Agungi Ajiran Road, Agungi, Lekki, Lagos     Lekki,
# 4029       4      3                   Lekki Phase 1, Lekki, Lagos     Lekki,
# 4245       3      2                           Ikate, Lekki, Lagos     Lekki,
# 4300       4      5                    GRA Phase 2, Magodo, Lagos    Magodo,
# 4336       3      3                Second Toll Gate, Lekki, Lagos     Lekki,
# 4338       4      3                                  Lekki, Lagos     Lekki,
#
#            price
# 1811   4,000,000
# 2539  15,000,000
# 3394   2,500,000
# 3395   1,400,000
# 3469   1,300,000
# 3472   1,300,000
# 4029   3,500,000
# 4245   2,500,000
# 4300   3,500,000
# 4336   2,500,000
# 4338   5,000,000

# %%
df.drop_duplicates()
# Out:
#       page                                              title  \
# 0        1  Renovated Block Of City View 4 Bedroom Apartme...
# 1        1                                           Miniflat
# 2        1                                     Nice Mini Flat
# 3        1                                    Luxury Miniflat
# 4        1                       Spacious 2 Bedroom Apartment
# ...    ...                                                ...
# 6526   311    Well Maintained Studio Apartment With Generator
# 6527   311  Well Built 3 Bedroom Luxury Apartment With Nic...
# 6528   311                                        A Mini Flat
# 6529   311                A Self Contained With Swimming Pool
# 6530   311                    Self Contained Shared Apartment
#
#                                           description bedrooms bathrooms  \
# 0                 4 bedroom flat / apartment for rent        4         4
# 1     1 bedroom mini flat (room and parlour) for rent        1         1
# 2     1 bedroom mini flat (room and parlour) for rent        1         1
# 3     1 bedroom mini flat (room and parlour) for rent        1         1
# 4                 2 bedroom flat / apartment for rent        2         2
# ...                                               ...      ...       ...
# 6526             Self contain (single rooms) for rent     None         1
# 6527              3 bedroom flat / apartment for rent        3         4
# 6528  1 bedroom mini flat (room and parlour) for rent        1         1
# 6529             Self contain (single rooms) for rent     None         1
# 6530             Self contain (single rooms) for rent     None         1
#
#      toilets garage                                           location  \
# 0          5      2  Banana Island Estate, Banana Island, Ikoyi, Lagos
# 1          2   None  Off Spg Road Igbo Efon Lekki Lagos State, Lekk...
# 2          1   None                   Royal Garden Estate, Ajah, Lagos
# 3          2      2     Off Durosimi Etti, Lekki Phase 1, Lekki, Lagos
# 4          3      3  Serene Area Off Palace Way, Oniru, Victoria Is...
# ...      ...    ...                                                ...
# 6526       1      1                        Lekki Phase 1, Lekki, Lagos
# 6527       4   None                  Ilaije, Mobil Estate, Ajah, Lagos
# 6528       1      2                              Chevron, Lekki, Lagos
# 6529       1      2                     Ekins Estate, Ado, Ajah, Lagos
# 6530       1      6                        Lekki Scheme 2, Ajah, Lagos
#
#      location_s       price
# 0        Ikoyi,  12,000,000
# 1        Lekki,   1,200,000
# 2         Ajah,   1,200,000
# 3        Lekki,   2,400,000
# 4         (VI),   3,500,000
# ...         ...         ...
# 6526     Lekki,   1,300,000
# 6527      Ajah,   1,700,000
# 6528     Lekki,   1,400,000
# 6529      Ajah,     400,000
# 6530      Ajah,     400,000
#
# [6520 rows x 10 columns]

# %%
df.rename(columns={'location_s':'city'}, inplace=True)

# %%
df['city'].unique()
# Out:
# array(['Ikoyi,', 'Lekki,', 'Ajah,', '(VI),', 'Shomolu,', 'Maryland,',
#        'Surulere,', 'Odofin,', 'Ojodu,', 'Yaba,', 'Gbagada,', 'Ikeja,',
#        'Ojota,', 'Kosofe,', 'Magodo,', 'Agege,', 'Ikorodu,', 'Ketu,',
#        'Ogudu,', 'North,', 'Ilupeju,', 'Isolo,', 'Mushin,', 'Ijede,',
#        'Ayobo,', 'Ipaja,', 'Ikotun,', 'City,', 'Alimosho,', 'Ojo,',
#        'Ifako-Ijaiye,', 'Isheri,', 'Ijaiye,', 'Epe,', 'Island,',
#        'Oshodi,', 'Idimu,', 'Apapa,'], dtype=object)

# %%
df['city'][6253].split(',')
# Out:
# ['Lekki', '']

# %%
df['city'] = df['city'].apply(lambda x:x.split(',')[0])

# %%
df['city']
# Out:
# 0       Ikoyi
# 1       Lekki
# 2        Ajah
# 3       Lekki
# 4        (VI)
#         ...
# 6526    Lekki
# 6527     Ajah
# 6528    Lekki
# 6529     Ajah
# 6530     Ajah
# Name: city, Length: 6531, dtype: object

# %%
df['city'].replace('(VI)', 'Victoria Island', inplace=True)

# %%
df['city'].replace('City', 'Eko Atlantic City', inplace=True)

# %%
df[df['city']=='North']
# Out:
#       page                                              title  \
# 276     14                            Standard 3 Bedroom Flat
# 321     16                            Standard 3 Bedroom Flat
# 331     16                           Standard 2 Bedroom Flats
# 362     18              Luxury 3 Bedroom Flat Ensuit With Pop
# 582     28                                     3 Bedroom Flat
# 1276    61                             Luxury 3 Bedroon Flats
# 1287    62  Brand New 3 Bedroom Apartment. With Wardrop. A...
# 1422    68                                    3 Bedrooms Flat
# 1423    68                                     2 Bedroom Flat
# 1425    68           Furnished Room, Self Contained Apartment
# 1487    71         Very Nice 2 Bedroom Flat (all Room Ensuit)
# 1544    74    Luxury 3 Bedroom Flat With Excellent Facilities
# 1857    89      Executive 3 Bedroom Flat With Bq In An Estate
# 1858    89  Newly Built 2 Bedroom Flat In A Serene Environ...
# 1909    91                         Lovely 2 Bedroom Apartment
# 2143   103    5 Bedroom Fully Detached Duplex With A Room Bq.
# 2648   127        Massive And Newly Built 3 Bedroom Apartment
# 2773   133               Luxury 4 Bedroom Available For Lease
# 2791   133                         Newly Built 2 Bedroom Flat
# 2817   135                     Newly Built 3bedroom Apartment
# 2923   140                   Lovely Built 2 Bedroom Apartment
# 3369   161                 Tastefully Finished 3 Bedroom Flat
# 3383   162                                     3 Bedroom Flat
# 3714   177                         Newly Built 2 Bedroom Flat
# 4135   197                           Brand New 3 Bedroom Flat
# 4408   210                                     2 Bedroom Flat
# 4516   216                                     2 Bedroom Flat
# 4527   216                         Newly Built 3 Bedroom Flat
# 4800   229                      Fantastic 2 Bedroom Apartment
# 4804   229                 Tastefully Finished 3 Bedroom Flat
# 5488   262                Luxuriously Finished 2 Bedroom Flat
# 5510   263  Top Notch 3 Bedroom Flat With Excellent Facili...
# 5591   267                  Newly Built Luxury 2 Bedroom Flat
# 5797   277                      Massive 3 Bedroom Flat Ensuit
# 5915   282  One Bedroom Self-contain With Excellent Facili...
# 5961   284  Luxurious, And Tastefully Built 2 Bedroom. (al...
# 6061   289  Beautiful 2 Bedroom Flat With Excellent Facili...
# 6101   291      Beautiful Mini Flat With Excellent Facilities
# 6255   298                         Newly Built 3 Bedroom Flat
#
#                                           description bedrooms bathrooms  \
# 276               3 bedroom flat / apartment for rent        3         3
# 321               3 bedroom flat / apartment for rent        3         3
# 331               2 bedroom flat / apartment for rent        2         2
# 362               3 bedroom flat / apartment for rent        3         3
# 582               3 bedroom flat / apartment for rent        3         3
# 1276              3 bedroom flat / apartment for rent        3         4
# 1287              3 bedroom flat / apartment for rent        3      None
# 1422              3 bedroom flat / apartment for rent        3         3
# 1423              2 bedroom flat / apartment for rent        2         2
# 1425             Self contain (single rooms) for rent     None         1
# 1487              2 bedroom flat / apartment for rent        2         2
# 1544              3 bedroom flat / apartment for rent        3      None
# 1857              4 bedroom flat / apartment for rent        4         5
# 1858              2 bedroom flat / apartment for rent        2         3
# 1909              2 bedroom flat / apartment for rent        2         2
# 2143              5 bedroom flat / apartment for rent        5      None
# 2648              3 bedroom flat / apartment for rent        3         3
# 2773              4 bedroom flat / apartment for rent        4      None
# 2791              2 bedroom flat / apartment for rent        2         2
# 2817              3 bedroom flat / apartment for rent        3         4
# 2923              2 bedroom flat / apartment for rent        2         2
# 3369              3 bedroom flat / apartment for rent        3         3
# 3383              3 bedroom flat / apartment for rent        3         3
# 3714              2 bedroom flat / apartment for rent        2         2
# 4135              3 bedroom flat / apartment for rent        3         3
# 4408              2 bedroom flat / apartment for rent        2         2
# 4516              2 bedroom flat / apartment for rent        2         2
# 4527              3 bedroom flat / apartment for rent        3         3
# 4800              2 bedroom flat / apartment for rent        2         2
# 4804              3 bedroom flat / apartment for rent        3         3
# 5488              2 bedroom flat / apartment for rent        2         2
# 5510              3 bedroom flat / apartment for rent        3         3
# 5591              2 bedroom flat / apartment for rent        2         2
# 5797              3 bedroom flat / apartment for rent        3         3
# 5915             Self contain (single rooms) for rent     None         1
# 5961              2 bedroom flat / apartment for rent        2         2
# 6061              2 bedroom flat / apartment for rent        2         2
# 6101  1 bedroom mini flat (room and parlour) for rent        1         2
# 6255              3 bedroom flat / apartment for rent        3         3
#
#      toilets garage                                           location   city  \
# 276        4   None                          Opic, Isheri North, Lagos  North
# 321        4   None                          Opic, Isheri North, Lagos  North
# 331        3   None                          Opic, Isheri North, Lagos  North
# 362        4      6          Oshorun Estate, Opic, Isheri North, Lagos  North
# 582        4      2                      Opic Gra, Isheri North, Lagos  North
# 1276       4      7          Airport Estate, Opic, Isheri North, Lagos  North
# 1287    None   None                          Opic, Isheri North, Lagos  North
# 1422       4      2                      Opic Gra, Isheri North, Lagos  North
# 1423       3      2  Back Of Jf Filling Station Opic Isheri North, ...  North
# 1425       1      1                                Isheri North, Lagos  North
# 1487       3   None                          Opic, Isheri North, Lagos  North
# 1544    None   None                  Isheri, Opic, Isheri North, Lagos  North
# 1857       5      3                          Opic, Isheri North, Lagos  North
# 1858       3      2                          Opic, Isheri North, Lagos  North
# 1909       3   None                          Opic, Isheri North, Lagos  North
# 2143    None   None                           GRA, Isheri North, Lagos  North
# 2648       4   None                          Opic, Isheri North, Lagos  North
# 2773    None   None                 Wisdom Estate, Isheri North, Lagos  North
# 2791       3   None                          Opic, Isheri North, Lagos  North
# 2817       4      2                          Opic, Isheri North, Lagos  North
# 2923       3   None          Oshorun Estate, Opic, Isheri North, Lagos  North
# 3369       4      2                     Gra, Opic, Isheri North, Lagos  North
# 3383       4      4             Opic Estate, Opic, Isheri North, Lagos  North
# 3714       3   None                          Opic, Isheri North, Lagos  North
# 4135       4      2                          Opic, Isheri North, Lagos  North
# 4408       3   None          Harmony Estate, Opic, Isheri North, Lagos  North
# 4516       3   None      Sparcklight Estate, Opic, Isheri North, Lagos  North
# 4527       4   None                          Opic, Isheri North, Lagos  North
# 4800       3   None          Oshorun Estate, Opic, Isheri North, Lagos  North
# 4804       4      2                          Opic, Isheri North, Lagos  North
# 5488       3      2                          Opic, Isheri North, Lagos  North
# 5510       4   None  Along Channels Tv Road, Opic, Isheri North, Lagos  North
# 5591       3   None                          Opic, Isheri North, Lagos  North
# 5797       3      6  Near Channels Television, Opic, Isheri North, ...  North
# 5915       1      6        Riverview Estate, Opic, Isheri North, Lagos  North
# 5961       3   None                          Opic, Isheri North, Lagos  North
# 6061       3   None        Riverview Estate, Opic, Isheri North, Lagos  North
# 6101       2   None       River View Estate, Opic, Isheri North, Lagos  North
# 6255       4   None                          Opic, Isheri North, Lagos  North
#
#           price
# 276   1,400,000
# 321   1,300,000
# 331   1,300,000
# 362   1,000,000
# 582   1,500,000
# 1276    700,000
# 1287  1,400,000
# 1422  1,500,000
# 1423  1,200,000
# 1425    500,000
# 1487    600,000
# 1544  2,200,000
# 1857  2,200,000
# 1858  1,000,000
# 1909  1,100,000
# 2143  3,000,000
# 2648  1,500,000
# 2773  2,000,000
# 2791  1,300,000
# 2817  1,500,000
# 2923    900,000
# 3369  1,500,000
# 3383  1,500,000
# 3714  1,000,000
# 4135  1,400,000
# 4408  1,000,000
# 4516    800,000
# 4527  1,600,000
# 4800  1,300,000
# 4804  1,500,000
# 5488  1,200,000
# 5510  1,000,000
# 5591  1,000,000
# 5797  1,000,000
# 5915    200,000
# 5961  1,200,000
# 6061    600,000
# 6101    450,000
# 6255  1,500,000

# %%
df['city'].replace('North,', 'Isheri North', inplace=True)

# %%
df.isnull().sum()
# Out:
# page              0
# title             0
# description       0
# bedrooms        629
# bathrooms       510
# toilets         360
# garage         2207
# location          0
# city              0
# price             0
# dtype: int64

# %%
df.fillna(0, inplace=True)

# %%
# Cleaning the string so we can easily convert to integers
df['price'] = df['price'].apply(lambda x:x.replace(',',''))

# %%
df.head()
# Out:
#    page                                              title  \
# 0     1  Renovated Block Of City View 4 Bedroom Apartme...
# 1     1                                           Miniflat
# 2     1                                     Nice Mini Flat
# 3     1                                    Luxury Miniflat
# 4     1                       Spacious 2 Bedroom Apartment
#
#                                        description bedrooms bathrooms toilets  \
# 0              4 bedroom flat / apartment for rent        4         4       5
# 1  1 bedroom mini flat (room and parlour) for rent        1         1       2
# 2  1 bedroom mini flat (room and parlour) for rent        1         1       1
# 3  1 bedroom mini flat (room and parlour) for rent        1         1       2
# 4              2 bedroom flat / apartment for rent        2         2       3
#
#   garage                                           location             city  \
# 0      2  Banana Island Estate, Banana Island, Ikoyi, Lagos            Ikoyi
# 1      0  Off Spg Road Igbo Efon Lekki Lagos State, Lekk...            Lekki
# 2      0                   Royal Garden Estate, Ajah, Lagos             Ajah
# 3      2     Off Durosimi Etti, Lekki Phase 1, Lekki, Lagos            Lekki
# 4      3  Serene Area Off Palace Way, Oniru, Victoria Is...  Victoria Island
#
#       price
# 0  12000000
# 1   1200000
# 2   1200000
# 3   2400000
# 4   3500000

# %%
# Converting from float to integers
df['bedrooms'] = df['bedrooms'].astype('int')
df['bathrooms'] = df['bathrooms'].astype('int')
df['toilets'] = df['toilets'].astype('int')
df['garage'] = df['garage'].astype('int')
df['price'] = df['price'].astype('int64')

# %%
df.dtypes
# Out:
# page            int64
# title          object
# description    object
# bedrooms        int32
# bathrooms       int32
# toilets         int32
# garage          int32
# location       object
# city           object
# price           int64
# dtype: object

# %%
df.to_csv('Properties.csv', index=False)

# %%
df = pd.read_csv('Properties.csv')

# %%
df['bedrooms'].value_counts()
# Out:
# 3    2342
# 2    1718
# 1    1322
# 0     629
# 4     480
# 5      30
# 6       8
# 8       1
# 7       1
# Name: bedrooms, dtype: int64

# %% [markdown]
# ### wow! there are bedrooms with *0* rooms. How is that even possible. Let's check the column properly in the next few cells

# %%
df[df['bedrooms']==0]
# Out:
#       page                                              title  \
# 5        1          Luxurious Self Contained With Own Kitchen
# 8        1                               Spacious Bq Self Con
# 15       1  A Spacious Room Self Contained Apartment In An...
# 16       1  A Newly Built Room Self Apartment In A Mini Es...
# 20       1                                     Self Contained
# ...    ...                                                ...
# 6522   311                        Luxurious Self Contain Room
# 6524   311  Newly Built, Pop Finishing. Upstairs & Downstairs
# 6526   311    Well Maintained Studio Apartment With Generator
# 6529   311                A Self Contained With Swimming Pool
# 6530   311                    Self Contained Shared Apartment
#
#                                description  bedrooms  bathrooms  toilets  \
# 5     Self contain (single rooms) for rent         0          0        0
# 8     Self contain (single rooms) for rent         0          1        1
# 15    Self contain (single rooms) for rent         0          0        1
# 16    Self contain (single rooms) for rent         0          1        1
# 20    Self contain (single rooms) for rent         0          1        1
# ...                                    ...       ...        ...      ...
# 6522  Self contain (single rooms) for rent         0          1        1
# 6524  Self contain (single rooms) for rent         0          1        1
# 6526  Self contain (single rooms) for rent         0          1        1
# 6529  Self contain (single rooms) for rent         0          1        1
# 6530  Self contain (single rooms) for rent         0          1        1
#
#       garage                                           location     city  \
# 5          0  Bourdillon Court Estate, Chevron Drive, Chevro...    Lekki
# 8          1   Bera Estate Chevron, Lekki Phase 2, Lekki, Lagos    Lekki
# 15         0              Apata Street, Onipanu, Shomolu, Lagos  Shomolu
# 16         0                          Palmgrove, Shomolu, Lagos  Shomolu
# 20         1                              Ologolo, Lekki, Lagos    Lekki
# ...      ...                                                ...      ...
# 6522       0                        Lekki Phase 1, Lekki, Lagos    Lekki
# 6524       0               Rockstone Ville Estate, Lekki, Lagos    Lekki
# 6526       1                        Lekki Phase 1, Lekki, Lagos    Lekki
# 6529       2                     Ekins Estate, Ado, Ajah, Lagos     Ajah
# 6530       6                        Lekki Scheme 2, Ajah, Lagos     Ajah
#
#         price
# 5      750000
# 8      500000
# 15     400000
# 16     500000
# 20    1200000
# ...       ...
# 6522   800000
# 6524   300000
# 6526  1300000
# 6529   400000
# 6530   400000
#
# [629 rows x 10 columns]

# %% [markdown]
# ### Okay! checking out bedrooms with 0 rooms, most of these bedrooms entries are have "Self contain(single rooms) for rent" as their description.
#
# ### Let's confirm that in the next cell

# %%
df.loc[(df['bedrooms']==0) & (df['description']=='Self contain (single rooms) for rent')]
# Out:
#       page                                              title  \
# 5        1          Luxurious Self Contained With Own Kitchen
# 8        1                               Spacious Bq Self Con
# 15       1  A Spacious Room Self Contained Apartment In An...
# 16       1  A Newly Built Room Self Apartment In A Mini Es...
# 20       1                                     Self Contained
# ...    ...                                                ...
# 6522   311                        Luxurious Self Contain Room
# 6524   311  Newly Built, Pop Finishing. Upstairs & Downstairs
# 6526   311    Well Maintained Studio Apartment With Generator
# 6529   311                A Self Contained With Swimming Pool
# 6530   311                    Self Contained Shared Apartment
#
#                                description  bedrooms  bathrooms  toilets  \
# 5     Self contain (single rooms) for rent         0          0        0
# 8     Self contain (single rooms) for rent         0          1        1
# 15    Self contain (single rooms) for rent         0          0        1
# 16    Self contain (single rooms) for rent         0          1        1
# 20    Self contain (single rooms) for rent         0          1        1
# ...                                    ...       ...        ...      ...
# 6522  Self contain (single rooms) for rent         0          1        1
# 6524  Self contain (single rooms) for rent         0          1        1
# 6526  Self contain (single rooms) for rent         0          1        1
# 6529  Self contain (single rooms) for rent         0          1        1
# 6530  Self contain (single rooms) for rent         0          1        1
#
#       garage                                           location     city  \
# 5          0  Bourdillon Court Estate, Chevron Drive, Chevro...    Lekki
# 8          1   Bera Estate Chevron, Lekki Phase 2, Lekki, Lagos    Lekki
# 15         0              Apata Street, Onipanu, Shomolu, Lagos  Shomolu
# 16         0                          Palmgrove, Shomolu, Lagos  Shomolu
# 20         1                              Ologolo, Lekki, Lagos    Lekki
# ...      ...                                                ...      ...
# 6522       0                        Lekki Phase 1, Lekki, Lagos    Lekki
# 6524       0               Rockstone Ville Estate, Lekki, Lagos    Lekki
# 6526       1                        Lekki Phase 1, Lekki, Lagos    Lekki
# 6529       2                     Ekins Estate, Ado, Ajah, Lagos     Ajah
# 6530       6                        Lekki Scheme 2, Ajah, Lagos     Ajah
#
#         price
# 5      750000
# 8      500000
# 15     400000
# 16     500000
# 20    1200000
# ...       ...
# 6522   800000
# 6524   300000
# 6526  1300000
# 6529   400000
# 6530   400000
#
# [626 rows x 10 columns]

# %% [markdown]
# ### As at the time we scraped the website, there 626 entries having "self contain(single rooms) for rent" in their description having 0 in the bedrooms column.

# %%
df[(df['bedrooms']==0)]
# Out:
#       page                                              title  \
# 5        1          Luxurious Self Contained With Own Kitchen
# 8        1                               Spacious Bq Self Con
# 15       1  A Spacious Room Self Contained Apartment In An...
# 16       1  A Newly Built Room Self Apartment In A Mini Es...
# 20       1                                     Self Contained
# ...    ...                                                ...
# 6522   311                        Luxurious Self Contain Room
# 6524   311  Newly Built, Pop Finishing. Upstairs & Downstairs
# 6526   311    Well Maintained Studio Apartment With Generator
# 6529   311                A Self Contained With Swimming Pool
# 6530   311                    Self Contained Shared Apartment
#
#                                description  bedrooms  bathrooms  toilets  \
# 5     Self contain (single rooms) for rent         0          0        0
# 8     Self contain (single rooms) for rent         0          1        1
# 15    Self contain (single rooms) for rent         0          0        1
# 16    Self contain (single rooms) for rent         0          1        1
# 20    Self contain (single rooms) for rent         0          1        1
# ...                                    ...       ...        ...      ...
# 6522  Self contain (single rooms) for rent         0          1        1
# 6524  Self contain (single rooms) for rent         0          1        1
# 6526  Self contain (single rooms) for rent         0          1        1
# 6529  Self contain (single rooms) for rent         0          1        1
# 6530  Self contain (single rooms) for rent         0          1        1
#
#       garage                                           location     city  \
# 5          0  Bourdillon Court Estate, Chevron Drive, Chevro...    Lekki
# 8          1   Bera Estate Chevron, Lekki Phase 2, Lekki, Lagos    Lekki
# 15         0              Apata Street, Onipanu, Shomolu, Lagos  Shomolu
# 16         0                          Palmgrove, Shomolu, Lagos  Shomolu
# 20         1                              Ologolo, Lekki, Lagos    Lekki
# ...      ...                                                ...      ...
# 6522       0                        Lekki Phase 1, Lekki, Lagos    Lekki
# 6524       0               Rockstone Ville Estate, Lekki, Lagos    Lekki
# 6526       1                        Lekki Phase 1, Lekki, Lagos    Lekki
# 6529       2                     Ekins Estate, Ado, Ajah, Lagos     Ajah
# 6530       6                        Lekki Scheme 2, Ajah, Lagos     Ajah
#
#         price
# 5      750000
# 8      500000
# 15     400000
# 16     500000
# 20    1200000
# ...       ...
# 6522   800000
# 6524   300000
# 6526  1300000
# 6529   400000
# 6530   400000
#
# [629 rows x 10 columns]

# %%
df.loc[(df['title']=='Spacious 4 Bedroom Flat ( Self-compound)')& (df['bedrooms']==0), 'bedrooms'] = 4

# %% [markdown]
# ### Okay we're done with the bedrooms column
#
# ### Let's  check the bathrooms and toilets columns

# %%
df['bathrooms'].unique()
# Out:
# array([4, 1, 2, 0, 3, 5, 6, 8, 7], dtype=int64)

# %%
bath = df[df['bathrooms']==0]

# %%
bath.head()
# Out:
#     page                                              title  \
# 5      1          Luxurious Self Contained With Own Kitchen
# 15     1  A Spacious Room Self Contained Apartment In An...
# 33     2               Mini Flat + Pool + Gym Lekki-phase-1
# 45     3                                     3 Bedroom Flat
# 46     3                           3 Bedroom Flat (ensuite)
#
#                                         description  bedrooms  bathrooms  \
# 5              Self contain (single rooms) for rent         0          0
# 15             Self contain (single rooms) for rent         0          0
# 33  1 bedroom mini flat (room and parlour) for rent         1          0
# 45              3 bedroom flat / apartment for rent         3          0
# 46              3 bedroom flat / apartment for rent         3          0
#
#     toilets  garage                                           location  \
# 5         0       0  Bourdillon Court Estate, Chevron Drive, Chevro...
# 15        1       0              Apata Street, Onipanu, Shomolu, Lagos
# 33        1       0                        Lekki Phase 1, Lekki, Lagos
# 45        0       0                  Apple Estate, Amuwo Odofin, Lagos
# 46        0       0  Oye Balogun Street, Itedo Estate, Off Freedom ...
#
#        city    price
# 5     Lekki   750000
# 15  Shomolu   400000
# 33    Lekki  1500000
# 45   Odofin  1500000
# 46    Lekki  2600000

# %%
bath['description'].unique()
# Out:
# array(['Self contain (single rooms) for rent',
#        '1 bedroom mini flat (room and parlour) for rent',
#        '3 bedroom flat / apartment for rent',
#        '2 bedroom flat / apartment for rent',
#        '1 bedroom flat / apartment for rent',
#        '4 bedroom flat / apartment for rent',
#        '5 bedroom flat / apartment for rent',
#        '6 bedroom flat / apartment for rent', 'Flat / apartment for rent'],
#       dtype=object)

# %%
df.loc[(df['description']=='Self contain (single rooms) for rent') |
       (df['description']=='1 bedroom mini flat (room and parlour) for rent') |
       (df['description']=='1 bedroom flat / apartment for rent') |
       (df['description']=='2 bedroom flat / apartment for rent') & (df['bathrooms']==0), 'bathrooms'] = 1

# %%
df.loc[(df['description']=='3 bedroom flat / apartment for rent') & (df['bathrooms']==0), 'bathrooms'] = 2

# %%
df.loc[(df['description']=='4 bedroom flat / apartment for rent') & (df['bathrooms']==0), 'bathrooms'] = 3

# %%
df.loc[(df['description']=='5 bedroom flat / apartment for rent') & (df['bathrooms']==0), 'bathrooms'] = 4

# %%
df.loc[(df['description']=='6 bedroom flat / apartment for rent') & (df['bathrooms']==0),'bathrooms'] = 5

# %%
df.loc[(df['title']=='Serviced & Furnished One Room Self-contained Bq') |
       (df['title']=='Newly Built & Completed Luxurious & Spacious 1room Self-contained Flat') & 
       (df['bathrooms']==0), 'bathrooms'] = 1

# %%
df.loc[(df['title']=='Spacious 4 Bedroom Flat ( Self-compound)')& (df['bathrooms']==0), 'bathrooms'] = 3

# %%
df['bathrooms'].unique()
# Out:
# array([4, 1, 2, 3, 5, 6, 8, 7], dtype=int64)

# %%
df['toilets'].unique()
# Out:
# array([5, 2, 1, 3, 0, 4, 6, 8, 7, 9], dtype=int64)

# %%
toilets = df[df['toilets']==0]

# %%
toilets['description'].unique()
# Out:
# array(['Self contain (single rooms) for rent',
#        '3 bedroom flat / apartment for rent',
#        '1 bedroom mini flat (room and parlour) for rent',
#        '2 bedroom flat / apartment for rent',
#        '1 bedroom flat / apartment for rent',
#        '4 bedroom flat / apartment for rent',
#        '5 bedroom flat / apartment for rent', 'Flat / apartment for rent',
#        '6 bedroom flat / apartment for rent'], dtype=object)

# %%
df.loc[(df['description']=='1 bedroom mini flat (room and parlour) for rent') | 
       (df['description']=='1 bedroom flat / apartment for rent') |
       (df['description']=='Self contain (single rooms) for rent') &
       (df['toilets']==0), 'toilets'] = 1

# %%
df.loc[(df['description']=='2 bedroom flat / apartment for rent') & (df['toilets']==0), 'toilets'] = 2

# %%
df.loc[(df['description']=='3 bedroom flat / apartment for rent') & (df['toilets']==0), 'toilets'] = 3

# %%
df.loc[(df['description']=='4 bedroom flat / apartment for rent') & (df['toilets']==0), 'toilets'] = 4

# %%
df.loc[(df['description']=='5 bedroom flat / apartment for rent') & (df['toilets']==0), 'toilets'] = 5

# %%
df.loc[(df['description']=='6 bedroom flat / apartment for rent') & (df['toilets']==0), 'toilets'] = 6

# %%
df.loc[(df['title']=='Serviced & Furnished One Room Self-contained Bq') |
       (df['title']=='Newly Built & Completed Luxurious & Spacious 1room Self-contained Flat') & 
       (df['toilets']==0), 'toilets'] = 1

# %%
df.loc[(df['title']=='Spacious 4 Bedroom Flat ( Self-compound)')& (df['toilets']==0), 'toilets'] = 4

# %%
df['toilets'].unique()
# Out:
# array([5, 1, 3, 4, 2, 6, 8, 7, 9], dtype=int64)

# %%
df.head()
# Out:
#    page                                              title  \
# 0     1  Renovated Block Of City View 4 Bedroom Apartme...
# 1     1                                           Miniflat
# 2     1                                     Nice Mini Flat
# 3     1                                    Luxury Miniflat
# 4     1                       Spacious 2 Bedroom Apartment
#
#                                        description  bedrooms  bathrooms  \
# 0              4 bedroom flat / apartment for rent         4          4
# 1  1 bedroom mini flat (room and parlour) for rent         1          1
# 2  1 bedroom mini flat (room and parlour) for rent         1          1
# 3  1 bedroom mini flat (room and parlour) for rent         1          1
# 4              2 bedroom flat / apartment for rent         2          2
#
#    toilets  garage                                           location  \
# 0        5       2  Banana Island Estate, Banana Island, Ikoyi, Lagos
# 1        1       0  Off Spg Road Igbo Efon Lekki Lagos State, Lekk...
# 2        1       0                   Royal Garden Estate, Ajah, Lagos
# 3        1       2     Off Durosimi Etti, Lekki Phase 1, Lekki, Lagos
# 4        3       3  Serene Area Off Palace Way, Oniru, Victoria Is...
#
#               city     price
# 0            Ikoyi  12000000
# 1            Lekki   1200000
# 2             Ajah   1200000
# 3            Lekki   2400000
# 4  Victoria Island   3500000

# %%
df.to_csv('Properties.csv', index=False)

# %% [markdown]
# ### Adebo Dolapo
# #### 15/2/2022
